# %%
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.11</span>
#         </div>

# %%
import os
os.chdir("/home/akniga/firefly")
import cclib
import pyfirefly

from ase import Atoms
from ase.io import *
from ase.optimize import BFGS
import ase.calculators.firefly as firefly
from ase.io.trajectory import Trajectory
from ase.optimize.fire import FIRE as QuasiNewton
import numpy as np
import nglview as ng

import importlib as imp

# %%
os.chdir("/home/akniga/NEB")
from ase import Atom
import pybel as pb
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.rdchem import Mol, Conformer

# %%
from ase.build import molecule
from ase.neb import NEB
from ase import Atom

# %%
_1 = firefly.xyz_to_atoms("Ae_1.xyz")
view_1 = ng.show_ase(_1)
view_1
# Out:
# NGLWidget()

# %%
_ts = firefly.xyz_to_atoms("tsguess.xyz")
view_1 = ng.show_ase(_ts)
view_1
# Out:
# NGLWidget()

# %%
_1.get_all_distances()

# %%
new_cont = Trajectory("opt_nitrosamine.traj")
_10 = new_cont[-1]
view_10 = ng.show_ase(_10)
view_10
# Out:
# NGLWidget()

# %%
neb = Trajectory("Ae_idpp.traj")
_neb = ng.show_asetraj(neb)
_neb
# Out:
# NGLWidget(count=3960)

# %%
os.chdir("/home/akniga/firefly")
imp.reload(pyfirefly)

# %%
mol_1 = firefly.ase_atoms_to_rdkit_molecule(_1, sanitize=False)
mol_10 = firefly.ase_atoms_to_rdkit_molecule(_10)
view_1 = ng.show_rdkit(mol_1)
view_10 = ng.show_rdkit(mol_10)

# %%
mol_1
print(Chem.MolToMolBlock(mol_1))

# %%
num = mol_1.GetNumConformers()
conf = mol_1.GetConformer()
#print(conf.GetPositions())
#print(mol_1.GetNumAtoms())
#a = Chem.MolToSmiles(mol_1)
rms = Chem.rdMolAlign.AlignMol(mol_1,mol_10, atomMap=zip(range(mol_1.GetNumAtoms()),range(mol_10.GetNumAtoms())))

# %%
mol_1.GetNumAtoms()

# %%
for i in

# %%
_1.write("_1.pdb", "proteindatabank")

# %%
mol1 = Chem.AddHs(mol_1)
AllChem.Compute2DCoords(mol_1)
from rdkit.Chem import Draw
Draw.MolToFile(mol_10,'_1.png')


from IPython.display import Image
Image("./_1.png")

# %%
mol = Chem.MolFromPDBFile("_1.pdb", sanitize=True)

# %%
print(Chem.MolToMolBlock(mol_1))

# %%
m1 = Chem.AddHs(mol_1)

# %%
for atom in mol_1.GetAtoms():
    print(atom.GetAtomicNum())

# %%
print(Chem.rdmolfiles.MolToMolBlock(mol1))

# %%
import pybel as pb

mol1 = next(pb.readfile("xyz", "Ae_1_1.xyz"))
mol2 = next(pb.readfile("xyz", "Ae_10.xyz"))

# %%
print(mol2.write("pdb"))

# %%
from rdkit.Chem import AllChem, rdMolAlign
rms = rdMolAlign.AlignMol(mol1,mol10)

# %%
options = {"MULT":"1","ICHARG":"1"}

images1 = [_1]

for i in range(7):
    images1.append(_1.copy())

images1.append(_ts)

neb = NEB(images1)
neb.interpolate("idpp")

# %%
images2 = [images1[-1]]

for i in range(9):
    images2.append(_ts.copy())

images2.append(_10)

neb = NEB(images2)
neb.interpolate("idpp")

# %%
images = images1 + images2[1:-1]
for image in images:
    image.set_calculator(firefly.Firefly(firefly.ase_atoms_to_rdkit_molecule(image), **options))

neb = NEB(images)

# %%
for i in range(len(images)):
    print(images[i].calc)

# %%
images.delete

# %%
images1

# %%
#imp.reload(firefly)

#Run NEB calculation
qn = QuasiNewton(neb, trajectory='Ae_idpp.traj',  logfile='Ae_idpp.log')
qn.run(fmax=0.05)
# Out:
# Total Energy = -11354.198010350001
# /tmp/tmpjqvcvmc1
# Total Energy = -11354.13785784454
# /tmp/tmp9syz2yfb
# Total Energy = -11353.062923785215
# /tmp/tmpx64cvjed
# Total Energy = -11352.407722091246
# /tmp/tmpi4iijhy3
# Total Energy = -11350.91860128425
# /tmp/tmphglj5q8e
# Total Energy = -11350.54144112536
# /tmp/tmpypxtqiw5
# Total Energy = -11349.101376524412
# /tmp/tmplpp68wp7
# Total Energy = -11348.292681570754
# /tmp/tmpyrki41qg
# Total Energy = -11349.225479972572
# /tmp/tmpcx3nsysv
# Total Energy = -11349.87594214532
# /tmp/tmp_vw71q8p
# Total Energy = -11349.217795232533
# /tmp/tmpjlj7cgus
# Total Energy = -11346.69089020896
# /tmp/tmplqvrlsrq
# Total Energy = -11343.64704208167
# /tmp/tmp7yupw_m4
# Total Energy = -11347.241272600078
# /tmp/tmpovez8w2m
# Total Energy = -11350.233612911585
# /tmp/tmphfoda5c2
# Total Energy = -11353.835876007728
# /tmp/tmptnxfj1hg
# Total Energy = -11354.198010350001
# /tmp/tmppzaho37k
# Total Energy = -11354.13785784454
# /tmp/tmpd883p5my
# Total Energy = -11353.062923785215
# /tmp/tmp1ynwp3e2
# Total Energy = -11352.407722091246
# /tmp/tmpgcxctnck
# Total Energy = -11350.91860128425
# /tmp/tmp3wnpf0qd
# Total Energy = -11350.54144112536
# /tmp/tmpcolur2nu
# Total Energy = -11349.101376524412
# /tmp/tmplu7u710r
# Total Energy = -11348.292681570754
# /tmp/tmpcydqb5_j
# Total Energy = -11349.225479972572
# /tmp/tmp9tiqevi_
# Total Energy = -11349.87594214532
# /tmp/tmpbtkhcq0a
# Total Energy = -11349.217795232533
# /tmp/tmp95zhzqkz
# Total Energy = -11346.69089020896
# /tmp/tmpaug5xqih
# Total Energy = -11343.64704208167
# /tmp/tmpuycxe5rw
# Total Energy = -11347.241272600078
# /tmp/tmpytxn3gtv
# Total Energy = -11350.233612911585
# /tmp/tmpag80csij
# Total Energy = -11353.835876007728
# /tmp/tmpuuifwycp
# Total Energy = -11354.198010350001
# /tmp/tmpsuhouyuh
# Total Energy = -11354.13785784454
# /tmp/tmpanlaubrn
# Total Energy = -11353.062923785215
# /tmp/tmp39la141n
# Total Energy = -11352.407722091246
# /tmp/tmpz251q5qo
# Total Energy = -11350.91860128425
# /tmp/tmpqlpqa17x
# Total Energy = -11350.54144112536
# /tmp/tmp51805e7q
# Total Energy = -11349.101376524412
# /tmp/tmp6nhgudzj
# Total Energy = -11348.292681570754
# /tmp/tmpoht1jn7q
# Total Energy = -11349.225479972572
# /tmp/tmp2gcbzafu
# Total Energy = -11349.87594214532
# /tmp/tmp6nhccziz
# Total Energy = -11349.217795232533
# /tmp/tmpxdtkuhxb
# Total Energy = -11346.69089020896
# /tmp/tmptj9yp8k3
# Total Energy = -11343.64704208167
# /tmp/tmpfwjox01b
# Total Energy = -11347.241272600078
# /tmp/tmphx0003un
# Total Energy = -11350.233612911585
# /tmp/tmp87u6vk49
# Total Energy = -11353.835876007728
# /tmp/tmp5oo3ft7c
# Total Energy = -11354.198010350001
# /tmp/tmpw5xsy5m5
# Total Energy = -11354.13785784454
# /tmp/tmpyu1l40hb
# Total Energy = -11353.062923785215
# /tmp/tmpkhpb84wg
# Total Energy = -11352.407722091246
# /tmp/tmpf5i_t301
# Total Energy = -11350.91860128425
# /tmp/tmpuqxdu_3m
# Total Energy = -11350.54144112536
# /tmp/tmp9fs03jij
# Total Energy = -11349.101376524412
# /tmp/tmp6wprllmr
# Total Energy = -11348.292681570754
# /tmp/tmp5qqngv73
# Total Energy = -11349.225479972572
# /tmp/tmpntib4rrd
# Total Energy = -11349.87594214532
# /tmp/tmpxjkvnpvl
# Total Energy = -11349.217795232533
# /tmp/tmpl8yhbzl9
# Total Energy = -11346.69089020896
# /tmp/tmpzcf6p9v7
# Total Energy = -11343.64704208167
# /tmp/tmpfoxf7flg
# Total Energy = -11347.241272600078
# /tmp/tmplea_gt6z
# Total Energy = -11350.233612911585
# /tmp/tmp5jvpv1_k
# Total Energy = -11353.835876007728
# /tmp/tmpd3_473id
# Total Energy = -11354.198010350001
# /tmp/tmpn09xk727
# Total Energy = -11354.13785784454
# /tmp/tmpqfjhx6ea
# Total Energy = -11353.062923785215
# /tmp/tmpo3zntsxg
# Total Energy = -11352.407722091246
# /tmp/tmpf4dmp47h
# Total Energy = -11350.91860128425
# /tmp/tmpvpkx1r1q
# Total Energy = -11350.54144112536
# /tmp/tmpsax_azc6
# Total Energy = -11349.101376524412
# /tmp/tmpb533iyi5
# Total Energy = -11348.292681570754
# /tmp/tmp7lxqvdj2
# Total Energy = -11349.225479972572
# /tmp/tmp_mm1sgjq
# Total Energy = -11349.87594214532
# /tmp/tmpvozgoh7o
# Total Energy = -11349.217795232533
# /tmp/tmpv2aohob4
# Total Energy = -11346.69089020896
# /tmp/tmpamrinjw7
# Total Energy = -11343.64704208167
# /tmp/tmpqikpx9f8
# Total Energy = -11347.241272600078
# /tmp/tmpzq80xq3_
# Total Energy = -11350.233612911585
# /tmp/tmptpmuh2mo
# Total Energy = -11353.835876007728
# /tmp/tmpzyyltpdm
# Total Energy = -11354.198010350001
# /tmp/tmpa8mbolyy
# Total Energy = -11354.13785784454
# /tmp/tmpgkvz7uth
# Total Energy = -11353.062923785215
# /tmp/tmpo4svju_u
# Total Energy = -11352.407722091246
# /tmp/tmpfjwmxpgf
# Total Energy = -11350.91860128425
# /tmp/tmpmxr5zxqi
# Total Energy = -11350.54144112536
# /tmp/tmp61htahij
# Total Energy = -11349.101376524412
# /tmp/tmp_ux7lxsh
# Total Energy = -11348.292681570754
# /tmp/tmpuwpbo5zk
# Total Energy = -11349.225479972572
# /tmp/tmpdiou99sc
# Total Energy = -11349.87594214532
# /tmp/tmpa7mkqh13
# Total Energy = -11349.217795232533
# /tmp/tmp8q3c19pg
# Total Energy = -11346.69089020896
# /tmp/tmp_odoir1v
# Total Energy = -11343.64704208167
# /tmp/tmp24pwmh7h
# Total Energy = -11347.241272600078
# /tmp/tmpqgvwff4n
# Total Energy = -11350.233612911585
# /tmp/tmphsum4s3u
# Total Energy = -11353.835876007728
# /tmp/tmp7mrfv_18
# Total Energy = -11354.198010350001
# /tmp/tmpnnqy5a2l
# Total Energy = -11354.13785784454
# /tmp/tmplcm47wx6
# Total Energy = -11353.062923785215
# /tmp/tmpkczajr9o
# Total Energy = -11352.407722091246
# /tmp/tmpohiqjgxs
# Total Energy = -11350.91860128425
# /tmp/tmp0yod3d4c
# Total Energy = -11350.54144112536
# /tmp/tmpreywzxfx
# Total Energy = -11349.101376524412
# /tmp/tmp1jiumqsi
# Total Energy = -11348.292681570754
# /tmp/tmpo6dphlv1
# Total Energy = -11349.225479972572
# /tmp/tmpls93765q
# Total Energy = -11349.87594214532
# /tmp/tmpm81mo6b2
# Total Energy = -11349.217795232533
# /tmp/tmpinay3m3q
# Total Energy = -11346.69089020896
# /tmp/tmpp52gbxqv
# Total Energy = -11343.64704208167
# /tmp/tmpj6xcaa1r
# Total Energy = -11347.241272600078
# /tmp/tmp676w6bxw
# Total Energy = -11350.233612911585
# /tmp/tmpbt0flq91
# Total Energy = -11353.835876007728
# /tmp/tmp8yoi3rzl
# Total Energy = -11354.198010350001
# /tmp/tmp_ydbiyeo
# Total Energy = -11354.13785784454
# /tmp/tmpu8_81mo8
# Total Energy = -11353.062923785215
# /tmp/tmpzx77wcki
# Total Energy = -11352.407722091246
# /tmp/tmpyreuu4_3
# Total Energy = -11350.91860128425
# /tmp/tmpp58866vm
# Total Energy = -11350.54144112536
# /tmp/tmpk82oi7w9
# Total Energy = -11349.101376524412
# /tmp/tmplmilrrs9
# Total Energy = -11348.292681570754
# /tmp/tmpqismckk9
# Total Energy = -11349.225479972572
# /tmp/tmp7_2nd6p8
# Total Energy = -11349.87594214532
# /tmp/tmp9w9nkwaq
# Total Energy = -11349.217795232533
# /tmp/tmp0fn2f6bj
# Total Energy = -11346.69089020896
# /tmp/tmp300ws9d0
# Total Energy = -11343.64704208167
# /tmp/tmpo7zpv8c0
# Total Energy = -11347.241272600078
# /tmp/tmpn6lxwocx
# Total Energy = -11350.233612911585
# /tmp/tmp3tf8n5px
# Total Energy = -11353.835876007728
# /tmp/tmpi5y208tc
# Total Energy = -11354.198010350001
# /tmp/tmpoh3qzntn
# Total Energy = -11354.13785784454
# /tmp/tmpbvhgmcjo
# Total Energy = -11353.062923785215
# /tmp/tmpeunxrnb9
# Total Energy = -11352.407722091246
# /tmp/tmpj1zhsxdj
# Total Energy = -11350.91860128425
# /tmp/tmp2esr6csp
# Total Energy = -11350.54144112536
# /tmp/tmp0oqiuwv_
# Total Energy = -11349.101376524412
# /tmp/tmpdro76jy0
# Total Energy = -11348.292681570754
# /tmp/tmp1ijjbteb
# Total Energy = -11349.225479972572
# /tmp/tmpkze5g6um
# Total Energy = -11349.87594214532
# /tmp/tmp1hu82cii
# Total Energy = -11349.217795232533
# /tmp/tmpl1rhxuxa
# Total Energy = -11346.69089020896
# /tmp/tmpk_8b_avu
# Total Energy = -11343.64704208167
# /tmp/tmpi0e9wbse
# Total Energy = -11347.241272600078
# /tmp/tmpg11xbjrl
# Total Energy = -11350.233612911585
# /tmp/tmpqe6ets3w
# Total Energy = -11353.835876007728
# /tmp/tmpyg5s0yu_
# Total Energy = -11354.198010350001
# /tmp/tmptyzzkzx_
# Total Energy = -11354.13785784454
# /tmp/tmpii0lv6d5
# Total Energy = -11353.062923785215
# /tmp/tmp77nmc63c
# Total Energy = -11352.407722091246
# /tmp/tmpbdl5svtk
# Total Energy = -11350.91860128425
# /tmp/tmp1r2klyjb
# Total Energy = -11350.54144112536
# /tmp/tmp9xhytc8b
# Total Energy = -11349.101376524412
# /tmp/tmp_yv86vr_
# Total Energy = -11348.292681570754
# /tmp/tmp9x0a4tdh
# Total Energy = -11349.225479972572
# /tmp/tmpwla22181
# Total Energy = -11349.87594214532
# /tmp/tmp2ozohqiv
# Total Energy = -11349.217795232533
# /tmp/tmpa3slfa6d
# Total Energy = -11346.69089020896
# /tmp/tmpell0xl1q
# Total Energy = -11343.64704208167
# /tmp/tmpaws5f5ih
# Total Energy = -11347.241272600078
# /tmp/tmpqw7qvl4r
# Total Energy = -11350.233612911585
# /tmp/tmpgvf04hhv
# Total Energy = -11353.835876007728
# /tmp/tmp13vhbyff
# Total Energy = -11354.198010350001
# /tmp/tmpz00_fyql
# Total Energy = -11354.13785784454
# /tmp/tmp75_a63n4
# Total Energy = -11353.062923785215
# /tmp/tmpcjvat7z_
# Total Energy = -11352.407722091246
# /tmp/tmpdr4x5zb8
# Total Energy = -11350.91860128425
# /tmp/tmplz95ckqz
# Total Energy = -11350.54144112536
# /tmp/tmp2jo1rqlf
# Total Energy = -11349.101376524412
# /tmp/tmpfp_jj55x
# Total Energy = -11348.292681570754
# /tmp/tmpfewmit2t
# Total Energy = -11349.225479972572
# /tmp/tmpgzm55i_i
# Total Energy = -11349.87594214532
# /tmp/tmp9o38o1z7
# Total Energy = -11349.217795232533
# /tmp/tmptq132dd3
# Total Energy = -11346.69089020896
# /tmp/tmpl874tr85
# Total Energy = -11343.64704208167
# /tmp/tmpuxxa92cw
# Total Energy = -11347.241272600078
# /tmp/tmpsjeadz8m
# Total Energy = -11350.233612911585
# /tmp/tmpdk9who8l
# Total Energy = -11353.835876007728
# /tmp/tmp3w3g1fos
# Total Energy = -11354.198010350001
# /tmp/tmpys84fju5
# Total Energy = -11354.13785784454
# /tmp/tmpy_ofl_b_
# Total Energy = -11353.062923785215
# /tmp/tmpv7yuv4zz
# Total Energy = -11352.407722091246
# /tmp/tmpxguiqc8w
# Total Energy = -11350.91860128425
# /tmp/tmpq6cnh0g_
# Total Energy = -11350.54144112536
# /tmp/tmpdrnxch21
# Total Energy = -11349.101376524412
# /tmp/tmptnibk42z
# Total Energy = -11348.292681570754
# /tmp/tmp9zv15043
# Total Energy = -11349.225479972572
# /tmp/tmpe5qegx15
# Total Energy = -11349.87594214532
# /tmp/tmptl2e8z1w
# Total Energy = -11349.217795232533
# /tmp/tmp0pic8fua
# Total Energy = -11346.69089020896
# /tmp/tmpfznyfucg
# Total Energy = -11343.64704208167
# /tmp/tmpl31shndn
# Total Energy = -11347.241272600078
# /tmp/tmp06z1hvv9
# Total Energy = -11350.233612911585
# /tmp/tmp11j_t9vs
# Total Energy = -11353.835876007728
# /tmp/tmpizol470e
# Total Energy = -11354.198010350001
# /tmp/tmp1y8_3nra
# Total Energy = -11354.13785784454
# /tmp/tmpn5liow5k
# Total Energy = -11353.062923785215
# /tmp/tmp7v9i5zro
# Total Energy = -11352.407722091246
# /tmp/tmplyzbfjg0
# Total Energy = -11350.91860128425
# /tmp/tmpfyh4a5ez
# Total Energy = -11350.54144112536
# /tmp/tmp_9q2hw8i
# Total Energy = -11349.101376524412
# /tmp/tmp6zg3hy1r
# Total Energy = -11348.292681570754
# /tmp/tmpyv7ls9ir
# Total Energy = -11349.225479972572
# /tmp/tmpqs6way99
# Total Energy = -11349.87594214532
# /tmp/tmpfn_19kcj
# Total Energy = -11349.217795232533
# /tmp/tmppddhutwc
# Total Energy = -11346.69089020896
# /tmp/tmpdya09v1s
# Total Energy = -11343.64704208167
# /tmp/tmpwxmz9h5m
# Total Energy = -11347.241272600078
# /tmp/tmpy_7jhcvm
# Total Energy = -11350.233612911585
# /tmp/tmp6y0troof
# Total Energy = -11353.835876007728
# /tmp/tmp0b7eug8n
# Total Energy = -11354.198010350001
# /tmp/tmplvxeko7y
# Total Energy = -11354.13785784454
# /tmp/tmpbdux7qeo
# Total Energy = -11353.062923785215
# /tmp/tmpkv1_3yhr
# Total Energy = -11352.407722091246
# /tmp/tmpc2hx3pls
# Total Energy = -11350.91860128425
# /tmp/tmpp2qyjaja
# Total Energy = -11350.54144112536
# /tmp/tmpz4mxibdw
# Total Energy = -11349.101376524412
# /tmp/tmpojt3l1sl
# Total Energy = -11348.292681570754
# /tmp/tmpyk4cau61
# Total Energy = -11349.225479972572
# /tmp/tmp0hdjjesj
# Total Energy = -11349.87594214532
# /tmp/tmps9xgm97w
# Total Energy = -11349.217795232533
# /tmp/tmpuebjp9lv
# Total Energy = -11346.69089020896
# /tmp/tmpluz28sz3
# Total Energy = -11343.64704208167
# /tmp/tmpe9urdv6t
# Total Energy = -11347.241272600078
# /tmp/tmpp6z9lg73
# Total Energy = -11350.233612911585
# /tmp/tmpxlhv8m7u
# Total Energy = -11353.835876007728
# /tmp/tmp_it3ohsh
# Total Energy = -11354.198010350001
# /tmp/tmpaoonnklx
# Total Energy = -11354.13785784454
# /tmp/tmpwrklvhkn
# Total Energy = -11353.062923785215
# /tmp/tmpw1klr7mu
# Total Energy = -11352.407722091246
# /tmp/tmpszzhj1cn
# Total Energy = -11350.91860128425
# /tmp/tmpncvf0ets
# Total Energy = -11350.54144112536
# /tmp/tmpcnhrpgco
# Total Energy = -11349.101376524412
# /tmp/tmpr3jvcs5y
# Total Energy = -11348.292681570754
# /tmp/tmpiigo58qc
# Total Energy = -11349.225479972572
# /tmp/tmp8iv1damr
# Total Energy = -11349.87594214532
# /tmp/tmp_lre0b5_
# Total Energy = -11349.217795232533
# /tmp/tmpvso27am0
# Total Energy = -11346.69089020896
# /tmp/tmpb609gv7k
# Total Energy = -11343.64704208167
# /tmp/tmprjr49e92
# Total Energy = -11347.241272600078
# /tmp/tmpyq0v7eix
# Total Energy = -11350.233612911585
# /tmp/tmpb5ps0088
# Total Energy = -11353.835876007728
# /tmp/tmpvog33jkt
# Total Energy = -11354.198010350001
# /tmp/tmp4em0xxld
# Total Energy = -11354.13785784454
# /tmp/tmpn1x9tm1k
# Total Energy = -11353.062923785215
# /tmp/tmp3at1zh10
# Total Energy = -11352.407722091246
# /tmp/tmp508ji0ba
# Total Energy = -11350.91860128425
# /tmp/tmp227_6bln
# Total Energy = -11350.54144112536
# /tmp/tmp19tul5hk
# Total Energy = -11349.101376524412
# /tmp/tmpxl3sxpg5
# Total Energy = -11348.292681570754
# /tmp/tmp1jr0mufd
# Total Energy = -11349.225479972572
# /tmp/tmp3y3_rhsf
# Total Energy = -11349.87594214532
# /tmp/tmpcvombflp
# Total Energy = -11349.217795232533
# /tmp/tmpx2689nr4
# Total Energy = -11346.69089020896
# /tmp/tmpnuugbnax
# Total Energy = -11343.64704208167
# /tmp/tmp_eg_ugch
# Total Energy = -11347.241272600078
# /tmp/tmpuktg7yh3
# Total Energy = -11350.233612911585
# /tmp/tmpsn8xaezm
# Total Energy = -11353.835876007728
# /tmp/tmps_d3p1b4
# Total Energy = -11354.198010350001
# /tmp/tmpegqghid4
# Total Energy = -11354.13785784454
# /tmp/tmpgtht527b
# Total Energy = -11353.062923785215
# /tmp/tmpy_zi7grm
# Total Energy = -11352.407722091246
# /tmp/tmpw3aqbg2c
# Total Energy = -11350.91860128425
# /tmp/tmpef0r8rof
# Total Energy = -11350.54144112536
# /tmp/tmphn8l_ac2
# Total Energy = -11349.101376524412
# /tmp/tmp47lp669p
# Total Energy = -11348.292681570754
# /tmp/tmptiau9hbk
# Total Energy = -11349.225479972572
# /tmp/tmp04lk0oe5
# Total Energy = -11349.87594214532
# /tmp/tmp6o3ujqxq
# Total Energy = -11349.217795232533
# /tmp/tmpafu11ag2
# Total Energy = -11346.69089020896
# /tmp/tmpkj2dx3zn
# Total Energy = -11343.64704208167
# /tmp/tmpt2u84x90
# Total Energy = -11347.241272600078
# /tmp/tmpm8ban18u
# Total Energy = -11350.233612911585
# /tmp/tmpzuyfyytj
# Total Energy = -11353.835876007728
# /tmp/tmp53xkxdz3
# Total Energy = -11354.198010350001
# /tmp/tmp0mlc5kw_
# Total Energy = -11354.13785784454
# /tmp/tmprnhp3bbp
# Total Energy = -11353.062923785215
# /tmp/tmpv3410dor
# Total Energy = -11352.407722091246
# /tmp/tmpwyvp8v2b
# Total Energy = -11350.91860128425
# /tmp/tmp8vg2mggz
# Total Energy = -11350.54144112536
# /tmp/tmpcua6grql
# Total Energy = -11349.101376524412
# /tmp/tmprv1shbdh
# Total Energy = -11348.292681570754
# /tmp/tmpw_1sk7vq
# Total Energy = -11349.225479972572
# /tmp/tmphtdj8uth
# Total Energy = -11349.87594214532
# /tmp/tmp51u068h9
# Total Energy = -11349.217795232533
# /tmp/tmpkjv9die5
# Total Energy = -11346.69089020896
# /tmp/tmp3aiuihoj
# Total Energy = -11343.64704208167
# /tmp/tmpar36s9kx
# Total Energy = -11347.241272600078
# /tmp/tmpc14qkaec
# Total Energy = -11350.233612911585
# /tmp/tmp7csuqi5g
# Total Energy = -11353.835876007728
# /tmp/tmp4ehoy9ds
# Total Energy = -11354.198010350001
# /tmp/tmpaihka9ha
# Total Energy = -11354.13785784454
# /tmp/tmpek662tnt
# Total Energy = -11353.062923785215
# /tmp/tmp4p2dcy1h
# Total Energy = -11352.407722091246
# /tmp/tmpkqfrhnxq
# Total Energy = -11350.91860128425
# /tmp/tmp4ppnq7oh
# Total Energy = -11350.54144112536
# /tmp/tmp52ejd79y
# Total Energy = -11349.101376524412
# /tmp/tmpxjt3r0uu
# Total Energy = -11348.292681570754
# /tmp/tmpxaw9ic1b
# Total Energy = -11349.225479972572
# /tmp/tmpeyvql2if
# Total Energy = -11349.87594214532
# /tmp/tmpvjgan6tp
# Total Energy = -11349.217795232533
# /tmp/tmpk8u1stjm
# Total Energy = -11346.69089020896
# /tmp/tmphf5w4dgj
# Total Energy = -11343.64704208167
# /tmp/tmpk4jr9l4c
# Total Energy = -11347.241272600078
# /tmp/tmpstclwvt8
# Total Energy = -11350.233612911585
# /tmp/tmp_fxhnzjl
# Total Energy = -11353.835876007728
# /tmp/tmpn5txs_14
# Total Energy = -11354.198010350001
# /tmp/tmpwf3bhya8
# Total Energy = -11354.13785784454
# /tmp/tmpznyhq0ic
# Total Energy = -11353.062923785215
# /tmp/tmph2cebfzl
# Total Energy = -11352.407722091246
# /tmp/tmpbf_mqqox
# Total Energy = -11350.91860128425
# /tmp/tmpjnhp8jen
# Total Energy = -11350.54144112536
# /tmp/tmp9jwkyd_g
# Total Energy = -11349.101376524412
# /tmp/tmpcu4oj6ij
# Total Energy = -11348.292681570754
# /tmp/tmp7q9fbe5o
# Total Energy = -11349.225479972572
# /tmp/tmpjobgctpz
# Total Energy = -11349.87594214532
# /tmp/tmpyw67nlgh
# Total Energy = -11349.217795232533
# /tmp/tmpja00kayi
# Total Energy = -11346.69089020896
# /tmp/tmp2wsd95fj
# Total Energy = -11343.64704208167
# /tmp/tmp9jr3_e13
# Total Energy = -11347.241272600078
# /tmp/tmpf4inv9cm
# Total Energy = -11350.233612911585
# /tmp/tmp6r2dq7di
# Total Energy = -11353.835876007728
# /tmp/tmpwdrd27ce
# Total Energy = -11354.198010350001
# /tmp/tmpenh90qic
# Total Energy = -11354.13785784454
# /tmp/tmpxk3orzey
# Total Energy = -11353.062923785215
# /tmp/tmpji8syp61
# Total Energy = -11352.407722091246
# /tmp/tmpvjivwzdt
# Total Energy = -11350.91860128425
# /tmp/tmp41ajc87s
# Total Energy = -11350.54144112536
# /tmp/tmp33y239sv
# Total Energy = -11349.101376524412
# /tmp/tmpswteand8
# Total Energy = -11348.292681570754
# /tmp/tmpsa5rz7cj
# Total Energy = -11349.225479972572
# /tmp/tmp6q6svikn
# Total Energy = -11349.87594214532
# /tmp/tmpqlc75wxo
# Total Energy = -11349.217795232533
# /tmp/tmpzd6ndws0
# Total Energy = -11346.69089020896
# /tmp/tmpmqei3yuq
# Total Energy = -11343.64704208167
# /tmp/tmpw8qj6nvw
# Total Energy = -11347.241272600078
# /tmp/tmpsexgfmhv
# Total Energy = -11350.233612911585
# /tmp/tmpvcr5h8cg
# Total Energy = -11353.835876007728
# /tmp/tmpnk9aoutu
# Total Energy = -11354.198010350001
# /tmp/tmpqih2e1g7
# Total Energy = -11354.13785784454
# /tmp/tmpc5rcu18e
# Total Energy = -11353.062923785215
# /tmp/tmpc1zdqfct
# Total Energy = -11352.407722091246
# /tmp/tmpxhezra0s
# Total Energy = -11350.91860128425
# /tmp/tmpoyi5y79z
# Total Energy = -11350.54144112536
# /tmp/tmp__nlp2f3
# Total Energy = -11349.101376524412
# /tmp/tmpd3vachh7
# Total Energy = -11348.292681570754
# /tmp/tmpfur01oea
# Total Energy = -11349.225479972572
# /tmp/tmpnr_9s121
# Total Energy = -11349.87594214532
# /tmp/tmpk2icfudh
# Total Energy = -11349.217795232533
# /tmp/tmp9a3dj6kq
# Total Energy = -11346.69089020896
# /tmp/tmp00ysg2tv
# Total Energy = -11343.64704208167
# /tmp/tmpd3y37wig
# Total Energy = -11347.241272600078
# /tmp/tmpscvkwtw0
# Total Energy = -11350.233612911585
# /tmp/tmpimlatqe5
# Total Energy = -11353.835876007728
# /tmp/tmpoh5bekjj
# Total Energy = -11354.198010350001
# /tmp/tmpl5rz0uh5
# Total Energy = -11354.13785784454
# /tmp/tmpxabu53s6
# Total Energy = -11353.062923785215
# /tmp/tmpufv46nke
# Total Energy = -11352.407722091246
# /tmp/tmpltidv1tp
# Total Energy = -11350.91860128425
# /tmp/tmplvfn2vlz
# Total Energy = -11350.54144112536
# /tmp/tmpyjbrcfyz
# Total Energy = -11349.101376524412
# /tmp/tmpjn71b7bz
# Total Energy = -11348.292681570754
# /tmp/tmp2ynyv7kt
# Total Energy = -11349.225479972572
# /tmp/tmp318zss_9
# Total Energy = -11349.87594214532
# /tmp/tmpkczko17w
# Total Energy = -11349.217795232533
# /tmp/tmp9bx5by3o
# Total Energy = -11346.69089020896
# /tmp/tmpf1wx5hcn
# Total Energy = -11343.64704208167
# /tmp/tmpbqo060rl
# Total Energy = -11347.241272600078
# /tmp/tmpo4t9smns
# Total Energy = -11350.233612911585
# /tmp/tmpbxmnfh2s
# Total Energy = -11353.835876007728
# /tmp/tmpqfkjyi8b
# Total Energy = -11354.198010350001
# /tmp/tmpbc8_8vq_
# Total Energy = -11354.13785784454
# /tmp/tmphfmeg4tb
# Total Energy = -11353.062923785215
# /tmp/tmpnywbpd9_
# Total Energy = -11352.407722091246
# /tmp/tmp5v5pgjzs
# Total Energy = -11350.91860128425
# /tmp/tmpz27iw0qu
# Total Energy = -11350.54144112536
# /tmp/tmpe8lms07_
# Total Energy = -11349.101376524412
# /tmp/tmp7y76wpmy
# Total Energy = -11348.292681570754
# /tmp/tmpwpmzhnrh
# Total Energy = -11349.225479972572
# /tmp/tmprwvdo473
# Total Energy = -11349.87594214532
# /tmp/tmpfk3od8_o
# Total Energy = -11349.217795232533
# /tmp/tmpgr5u3yr0
# Total Energy = -11346.69089020896
# /tmp/tmpssqielff
# Total Energy = -11343.64704208167
# /tmp/tmplnunwypb
# Total Energy = -11347.241272600078
# /tmp/tmp09wjg7k9
# Total Energy = -11350.233612911585
# /tmp/tmpmsqp1h_9
# Total Energy = -11353.835876007728
# /tmp/tmpauywtbbs
# Total Energy = -11354.198010350001
# /tmp/tmpz1ajwon6
# Total Energy = -11354.13785784454
# /tmp/tmpw74pizzg
# Total Energy = -11353.062923785215
# /tmp/tmpmlo85zz6
# Total Energy = -11352.407722091246
# /tmp/tmpk6_umo4t
# Total Energy = -11350.91860128425
# /tmp/tmpaji7o8n_
# Total Energy = -11350.54144112536
# /tmp/tmpwggwppi8
# Total Energy = -11349.101376524412
# /tmp/tmpj8v8buea
# Total Energy = -11348.292681570754
# /tmp/tmplcd9rsg7
# Total Energy = -11349.225479972572
# /tmp/tmph6zyx3j7
# Total Energy = -11349.87594214532
# /tmp/tmpma273k74
# Total Energy = -11349.217795232533
# /tmp/tmp7cer1opa
# Total Energy = -11346.69089020896
# /tmp/tmpdgo1eqvp
# Total Energy = -11343.64704208167
# /tmp/tmp0dvsuj2_
# Total Energy = -11347.241272600078
# /tmp/tmp_woztu10
# Total Energy = -11350.233612911585
# /tmp/tmpobmc6tnm
# Total Energy = -11353.835876007728
# /tmp/tmp3iu1brmp
# Total Energy = -11354.198010350001
# /tmp/tmp0w5qznjj
# Total Energy = -11354.13785784454
# /tmp/tmp3zik02j8
# Total Energy = -11353.062923785215
# /tmp/tmprz5jih14
# Total Energy = -11352.407722091246
# /tmp/tmp74yu0iy4
# Total Energy = -11350.91860128425
# /tmp/tmpdnkb0zky
# Total Energy = -11350.54144112536
# /tmp/tmpvoa_api8
# Total Energy = -11349.101376524412
# /tmp/tmp557lfn_1
# Total Energy = -11348.292681570754
# /tmp/tmp_59_ntfd
# Total Energy = -11349.225479972572
# /tmp/tmp7l1otr4c
# Total Energy = -11349.87594214532
# /tmp/tmpia0fufat
# Total Energy = -11349.217795232533
# /tmp/tmps5pwfbqz
# Total Energy = -11346.69089020896
# /tmp/tmpqxiphlgi
# Total Energy = -11343.64704208167
# /tmp/tmpr7nspzgb
# Total Energy = -11347.241272600078
# /tmp/tmpj18qqj72
# Total Energy = -11350.233612911585
# /tmp/tmp_na8edkb
# Total Energy = -11353.835876007728
# /tmp/tmpn93cjrhm
# Total Energy = -11354.198010350001
# /tmp/tmpl49m6g2u
# Total Energy = -11354.13785784454
# /tmp/tmpa3zv8q7s
# Total Energy = -11353.062923785215
# /tmp/tmpa7zaa_je
# Total Energy = -11352.407722091246
# /tmp/tmpcphbs4pe
# Total Energy = -11350.91860128425
# /tmp/tmpv5dlxlwg
# Total Energy = -11350.54144112536
# /tmp/tmpxo8wxugz
# Total Energy = -11349.101376524412
# /tmp/tmp5_6e7d__
# Total Energy = -11348.292681570754
# /tmp/tmpo3sv7ejm
# Total Energy = -11349.225479972572
# /tmp/tmpskivsyz8
# Total Energy = -11349.87594214532
# /tmp/tmpv8i_x_uq
# Total Energy = -11349.217795232533
# /tmp/tmpw181bwhd
# Total Energy = -11346.69089020896
# /tmp/tmp88wyx2mb
# Total Energy = -11343.64704208167
# /tmp/tmpxibp2wgx
# Total Energy = -11347.241272600078
# /tmp/tmpm4vspaiu
# Total Energy = -11350.233612911585
# /tmp/tmp03c7h8c8
# Total Energy = -11353.835876007728
# /tmp/tmp5ed7f8a3
# Total Energy = -11354.198010350001
# /tmp/tmpdw1vxoi1
# Total Energy = -11354.13785784454
# /tmp/tmpauawfsfo
# Total Energy = -11353.062923785215
# /tmp/tmp458fhu67
# Total Energy = -11352.407722091246
# /tmp/tmpqub2_7cn
# Total Energy = -11350.91860128425
# /tmp/tmp7g_40ij1
# Total Energy = -11350.54144112536
# /tmp/tmpp9i131l1
# Total Energy = -11349.101376524412
# /tmp/tmpjnv0wpbs
# Total Energy = -11348.292681570754
# /tmp/tmprjs13x7k
# Total Energy = -11349.225479972572
# /tmp/tmp9ht8q5rf
# Total Energy = -11349.87594214532
# /tmp/tmpdhg3iv4y
# Total Energy = -11349.217795232533
# /tmp/tmpsnb40gqn
# Total Energy = -11346.69089020896
# /tmp/tmp2mjugchy
# Total Energy = -11343.64704208167
# /tmp/tmp_zoe2dyx
# Total Energy = -11347.241272600078
# /tmp/tmparnprgb9
# Total Energy = -11350.233612911585
# /tmp/tmpp_3guokx
# Total Energy = -11353.835876007728
# /tmp/tmpkvhv5yo3
# Total Energy = -11354.198010350001
# /tmp/tmpzr80zsh5
# Total Energy = -11354.13785784454
# /tmp/tmpu7_2asvy
# Total Energy = -11353.062923785215
# /tmp/tmpd232lh0e
# Total Energy = -11352.407722091246
# /tmp/tmp8sp8ts4o
# Total Energy = -11350.91860128425
# /tmp/tmpzuy0zj61
# Total Energy = -11350.54144112536
# /tmp/tmpv9y1aie6
# Total Energy = -11349.101376524412
# /tmp/tmp08dlzbyx
# Total Energy = -11348.292681570754
# /tmp/tmphg8_o7jz
# Total Energy = -11349.225479972572
# /tmp/tmp10v38_2s
# Total Energy = -11349.87594214532
# /tmp/tmposa6qyuk
# Total Energy = -11349.217795232533
# /tmp/tmppgfcdo2x
# Total Energy = -11346.69089020896
# /tmp/tmp8t9fqx3b
# Total Energy = -11343.64704208167
# /tmp/tmp0vod1dp2
# Total Energy = -11347.241272600078
# /tmp/tmp_byvkkje
# Total Energy = -11350.233612911585
# /tmp/tmpvymw8k2d
# Total Energy = -11353.835876007728
# /tmp/tmpowc93inl
# Total Energy = -11354.198010350001
# /tmp/tmpp6ofn1b3
# Total Energy = -11354.13785784454
# /tmp/tmpa88rlllm
# Total Energy = -11353.062923785215
# /tmp/tmp93wyzjuu
# Total Energy = -11352.407722091246
# /tmp/tmph0q14tcg
# Total Energy = -11350.91860128425
# /tmp/tmph4cvbwmx
# Total Energy = -11350.54144112536
# /tmp/tmpo2sfu3wz
# Total Energy = -11349.101376524412
# /tmp/tmpglqkxdsi
# Total Energy = -11348.292681570754
# /tmp/tmpb33svzd7
# Total Energy = -11349.225479972572
# /tmp/tmp3yzyibeu
# Total Energy = -11349.87594214532
# /tmp/tmppy3ol9tn
# Total Energy = -11349.217795232533
# /tmp/tmp8uhywhou
# Total Energy = -11346.69089020896
# /tmp/tmpi2acd8c7
# Total Energy = -11343.64704208167
# /tmp/tmpn1ajng9m
# Total Energy = -11347.241272600078
# /tmp/tmpqrxg23cx
# Total Energy = -11350.233612911585
# /tmp/tmpsahxr3sk
# Total Energy = -11353.835876007728
# /tmp/tmp6kmoe1zp
# Total Energy = -11354.198010350001
# /tmp/tmpfxd5o9mm
# Total Energy = -11354.13785784454
# /tmp/tmpwm_mf_v4
# Total Energy = -11353.062923785215
# /tmp/tmpgjwg4wzd
# Total Energy = -11352.407722091246
# /tmp/tmpxucunbuw
# Total Energy = -11350.91860128425
# /tmp/tmpqyng4e8a
# Total Energy = -11350.54144112536
# /tmp/tmp2p7j0bjm
# Total Energy = -11349.101376524412
# /tmp/tmp463vzm5v
# Total Energy = -11348.292681570754
# /tmp/tmp_qo70wzj
# Total Energy = -11349.225479972572
# /tmp/tmpus7bfdnh
# Total Energy = -11349.87594214532
# /tmp/tmp0ij98w6a
# Total Energy = -11349.217795232533
# /tmp/tmpb436zcir
# Total Energy = -11346.69089020896
# /tmp/tmp453ixjh4
# Total Energy = -11343.64704208167
# /tmp/tmpuim3qjtq
# Total Energy = -11347.241272600078
# /tmp/tmpppd6o5of
# Total Energy = -11350.233612911585
# /tmp/tmp2n9jp2zg
# Total Energy = -11353.835876007728
# /tmp/tmpv8xpd1f_
# Total Energy = -11354.198010350001
# /tmp/tmplxdjs0j5
# Total Energy = -11354.13785784454
# /tmp/tmp88jj8w6m
# Total Energy = -11353.062923785215
# /tmp/tmpt3ruoh78
# Total Energy = -11352.407722091246
# /tmp/tmpumes425c
# Total Energy = -11350.91860128425
# /tmp/tmp2gh_hksi
# Total Energy = -11350.54144112536
# /tmp/tmpv8al1_1_
# Total Energy = -11349.101376524412
# /tmp/tmpa8qhms89
# Total Energy = -11348.292681570754
# /tmp/tmplyzsfp7z
# Total Energy = -11349.225479972572
# /tmp/tmpws86_tck
# Total Energy = -11349.87594214532
# /tmp/tmp1ft5tk9p
# Total Energy = -11349.217795232533
# /tmp/tmphw5005w9
# Total Energy = -11346.69089020896
# /tmp/tmp_jqtge5_
# Total Energy = -11343.64704208167
# /tmp/tmpq4h7ruvn
# Total Energy = -11347.241272600078
# /tmp/tmpsobupwoz
# Total Energy = -11350.233612911585
# /tmp/tmp1gp_zvhy
# Total Energy = -11353.835876007728
# /tmp/tmp82ryqto2
# Total Energy = -11354.198010350001
# /tmp/tmp8mi0dk62
# Total Energy = -11354.13785784454
# /tmp/tmpty3dh87i
# Total Energy = -11353.062923785215
# /tmp/tmpr7qj6ouy
# Total Energy = -11352.407722091246
# /tmp/tmpunlqdnho
# Total Energy = -11350.91860128425
# /tmp/tmplas14wnn
# Total Energy = -11350.54144112536
# /tmp/tmpsvpaxh_m
# Total Energy = -11349.101376524412
# /tmp/tmpqf86j8hm
# Total Energy = -11348.292681570754
# /tmp/tmpo7gq4dxm
# Total Energy = -11349.225479972572
# /tmp/tmp7e4z0igd
# Total Energy = -11349.87594214532
# /tmp/tmpcar597p1
# Total Energy = -11349.217795232533
# /tmp/tmpgryuscbq
# Total Energy = -11346.69089020896
# /tmp/tmp99v28l1x
# Total Energy = -11343.64704208167
# /tmp/tmpkx4gnog4
# Total Energy = -11347.241272600078
# /tmp/tmp91zmb9x6
# Total Energy = -11350.233612911585
# /tmp/tmps9oyfpgr
# Total Energy = -11353.835876007728
# /tmp/tmpi1_1a_bs
# Total Energy = -11354.198010350001
# /tmp/tmp_wpsq1ut
# Total Energy = -11354.13785784454
# /tmp/tmpjk5l2tdg
# Total Energy = -11353.062923785215
# /tmp/tmpf3jz6mil
# Total Energy = -11352.407722091246
# /tmp/tmpvx72bpl3
# Total Energy = -11350.91860128425
# /tmp/tmp6f3bazs8
# Total Energy = -11350.54144112536
# /tmp/tmpmvo5_pct
# Total Energy = -11349.101376524412
# /tmp/tmp7utnrwms
# Total Energy = -11348.292681570754
# /tmp/tmp7m3mvl11
# Total Energy = -11349.225479972572
# /tmp/tmp8vvufbao
# Total Energy = -11349.87594214532
# /tmp/tmpwmdcs7b0
# Total Energy = -11349.217795232533
# /tmp/tmpcewnzx9b
# Total Energy = -11346.69089020896
# /tmp/tmpb1atzj5f
# Total Energy = -11343.64704208167
# /tmp/tmpm_qoq4gz
# Total Energy = -11347.241272600078
# /tmp/tmpebfe39xl
# Total Energy = -11350.233612911585
# /tmp/tmpswskq5ig
# Total Energy = -11353.835876007728
# /tmp/tmpnslvfizh
# Total Energy = -11354.198010350001
# /tmp/tmpwqlpw9us
# Total Energy = -11354.13785784454
# /tmp/tmpgqcudhxr
# Total Energy = -11353.062923785215
# /tmp/tmp1l_z5s8t
# Total Energy = -11352.407722091246
# /tmp/tmp5kbrfnxf
# Total Energy = -11350.91860128425
# /tmp/tmpy6wiqa3z
# Total Energy = -11350.54144112536
# /tmp/tmpey9cxkcj
# Total Energy = -11349.101376524412
# /tmp/tmp8rwlo2qx
# Total Energy = -11348.292681570754
# /tmp/tmpydvse01u
# Total Energy = -11349.225479972572
# /tmp/tmp4urfy2cw
# Total Energy = -11349.87594214532
# /tmp/tmphrwz5rqg
# Total Energy = -11349.217795232533
# /tmp/tmprp1rtnpl
# Total Energy = -11346.69089020896
# /tmp/tmpxjdnmgnp
# Total Energy = -11343.64704208167
# /tmp/tmp84pi74ot
# Total Energy = -11347.241272600078
# /tmp/tmp2x5uput8
# Total Energy = -11350.233612911585
# /tmp/tmp6meo2o65
# Total Energy = -11353.835876007728
# /tmp/tmp9_r90jxm
# Total Energy = -11354.198010350001
# /tmp/tmp364y6rnm
# Total Energy = -11354.13785784454
# /tmp/tmpb_lpn200
# Total Energy = -11353.062923785215
# /tmp/tmp5hd2_f8g
# Total Energy = -11352.407722091246
# /tmp/tmp0trof_3z
# Total Energy = -11350.91860128425
# /tmp/tmp5auoeyyk
# Total Energy = -11350.54144112536
# /tmp/tmpmcnexqz8
# Total Energy = -11349.101376524412
# /tmp/tmpxmy5t4bx
# Total Energy = -11348.292681570754
# /tmp/tmpv2mrqeny
# Total Energy = -11349.225479972572
# /tmp/tmpmgkcwu6r
# Total Energy = -11349.87594214532
# /tmp/tmpm45fpdv2
# Total Energy = -11349.217795232533
# /tmp/tmpozoot429
# Total Energy = -11346.69089020896
# /tmp/tmprmnkip9n
# Total Energy = -11343.64704208167
# /tmp/tmpmnv99dne
# Total Energy = -11347.241272600078
# /tmp/tmpy0fxvc1m
# Total Energy = -11350.233612911585
# /tmp/tmp0tsnvq8_
# Total Energy = -11353.835876007728
# /tmp/tmpnemddsz9
# Total Energy = -11354.198010350001
# /tmp/tmphlf5jiwg
# Total Energy = -11354.13785784454
# /tmp/tmpfxz_ziuv
# Total Energy = -11353.062923785215
# /tmp/tmp0cbda6i9
# Total Energy = -11352.407722091246
# /tmp/tmpbahtw1iw
# Total Energy = -11350.91860128425
# /tmp/tmpxcvs_575
# Total Energy = -11350.54144112536
# /tmp/tmpytwvicel
# Total Energy = -11349.101376524412
# /tmp/tmp5om6wqxo
# Total Energy = -11348.292681570754
# /tmp/tmp8ut8ydpr
# Total Energy = -11349.225479972572
# /tmp/tmpnm0y16l4
# Total Energy = -11349.87594214532
# /tmp/tmpkdgonfu2
# Total Energy = -11349.217795232533
# /tmp/tmpj44vt_a1
# Total Energy = -11346.69089020896
# /tmp/tmp4vnpkep6
# Total Energy = -11343.64704208167
# /tmp/tmpp3ns7f8x
# Total Energy = -11347.241272600078
# /tmp/tmpzsxct0q5
# Total Energy = -11350.233612911585
# /tmp/tmpgmkb_qnx
# Total Energy = -11353.835876007728
# /tmp/tmp11spxpr3
# Total Energy = -11354.198010350001
# /tmp/tmp6aliiexh
# Total Energy = -11354.13785784454
# /tmp/tmph2me0al9
# Total Energy = -11353.062923785215
# /tmp/tmpny270w3y
# Total Energy = -11352.407722091246
# /tmp/tmpjbtb4vx9
# Total Energy = -11350.91860128425
# /tmp/tmp3zcgfk8b
# Total Energy = -11350.54144112536
# /tmp/tmpfx2y_w5s
# Total Energy = -11349.101376524412
# /tmp/tmpixuol1zl
# Total Energy = -11348.292681570754
# /tmp/tmpxpkme02i
# Total Energy = -11349.225479972572
# /tmp/tmpp0lv5fik
# Total Energy = -11349.87594214532
# /tmp/tmpz9x2eyel
# Total Energy = -11349.217795232533
# /tmp/tmpx58jbd1y
# Total Energy = -11346.69089020896
# /tmp/tmpfoa04ixl
# Total Energy = -11343.64704208167
# /tmp/tmp3ihbpact
# Total Energy = -11347.241272600078
# /tmp/tmpmdoi7md_
# Total Energy = -11350.233612911585
# /tmp/tmp4pksvh_2
# Total Energy = -11353.835876007728
# /tmp/tmp79aecobk
# Total Energy = -11354.198010350001
# /tmp/tmpkbrnua51
# Total Energy = -11354.13785784454
# /tmp/tmp7megj1vo
# Total Energy = -11353.062923785215
# /tmp/tmpm9b8b105
# Total Energy = -11352.407722091246
# /tmp/tmpuuba1plj
# Total Energy = -11350.91860128425
# /tmp/tmpb5o_gb89
# Total Energy = -11350.54144112536
# /tmp/tmpuui5wq9p
# Total Energy = -11349.101376524412
# /tmp/tmp89uirnvo
# Total Energy = -11348.292681570754
# /tmp/tmp4_hc6kw6
# Total Energy = -11349.225479972572
# /tmp/tmpfp1ogv9n
# Total Energy = -11349.87594214532
# /tmp/tmp6e_8bu1d
# Total Energy = -11349.217795232533
# /tmp/tmpinraxke1
# Total Energy = -11346.69089020896
# /tmp/tmp0edlcrx1
# Total Energy = -11343.64704208167
# /tmp/tmp2dy8go3_
# Total Energy = -11347.241272600078
# /tmp/tmpbul4vqhk
# Total Energy = -11350.233612911585
# /tmp/tmpzbq_g337

# %%
imp.reload(firefly)

# %%
images2

# %%
for image in images:
    image.set_calculator(firefly.Firefly(firefly.ase_atoms_to_rdkit_molecule(image), **options))

# %%
 images.append(_10.copy())

# %%
neb = NEB(images, remove_rotation_and_translation=True)
neb.interpolate("idpp")

# %%
import cclib

filename = "/home/akniga/chro/Diazotization/scan1/scan1.out"
data = cclib.io.ccread(filename)
print("There are %i atoms and %i MOs" % (data.natom, data.nmo))

# %%
images[]

# %%
fuck = ng.show_ase(images[14])
fuck

# %%
for key, value in i.items():
    if str(value).isdigit():
        print("YA")

# %%
i.get("a")

# %%
for i in i.keys():
    print(i)

# %%
print("privet")
# Out:
# privet

# %%
for i in os.listdir():
    print(i)
# Out:
# init_opt.xyz
# .ipynb_checkpoints
# no+ani_init.xyz
# init.traj
# tmp25t1bu4q
# no+h2o+ani_init_opt.ipynb
# tmp5zxvjleh
# tsguess.xyz
# init_viz.ipynb
# atoms
# Untitled.ipynb
# no+ani_init.sdf
# no+ani_init.pdb
# no_ad_init
# Untitled1.ipynb
# Untitled2.ipynb
# tmpxcccotr6
# tmp63j8a0zg
# tmp3khc3_wt
# init1.traj
# tmp1zmefs01
# tmpq53siy46
# opt.xyz
# opt_init.traj
# Untitled3.ipynb
# init.xyz
# init.pdb
# final.xyz
# final_opt.ipynb
# final.xyz.pdb
# opt_final.traj
# final
# final.pdb
# Ae_1.xyz
# Ae_10.xyz
# neb.ipynb
# Ae_idpp.log
# Ae_idpp.traj
# _1.traj
# opt_final_new.traj
# Ae_1_opt.xyz
# opt_nitrosamine.traj
# Untitled4.ipynb
# Ae_1_1.xyz
# _1.pdb
# _1.png
# _10.png
# guess_Ae.txt
# Untitled5.ipynb
# tmpb805tkh5
# tmp8dvfmy1l
# tmpkle9u8ow

# %%
# !ls
# Out:
# _10.png		 final.pdb	  no+ani_init.sdf	     tmp8dvfmy1l
# _1.pdb		 final.xyz	  no+ani_init.xyz	     tmpb805tkh5
# _1.png		 final.xyz.pdb	  no+h2o+ani_init_opt.ipynb  tmpkle9u8ow
# _1.traj		 guess_Ae.txt	  opt_final_new.traj	     tmpq53siy46
# Ae_10.xyz	 init1.traj	  opt_final.traj	     tmpxcccotr6
# Ae_1_1.xyz	 init_opt.xyz	  opt_init.traj		     tsguess.xyz
# Ae_1_opt.xyz	 init.pdb	  opt_nitrosamine.traj	     Untitled1.ipynb
# Ae_1.xyz	 init.traj	  opt.xyz		     Untitled2.ipynb
# Ae_idpp.log	 init_viz.ipynb   tmp1zmefs01		     Untitled3.ipynb
# Ae_idpp.traj	 init.xyz	  tmp25t1bu4q		     Untitled4.ipynb
# atoms		 neb.ipynb	  tmp3khc3_wt		     Untitled5.ipynb
# final		 no_ad_init	  tmp5zxvjleh		     Untitled.ipynb
# final_opt.ipynb  no+ani_init.pdb  tmp63j8a0zg
